# %%
lists = []
count = 1
#s = int(input())
for j in range(12):                  #10^6=1000000
    count *= 10
    lists = []
    i = 0
    for i in range(1,count+1):
        if i % 7 == 0:
            lists.append(i)
    print(count,"以内，共有7的倍数",len(lists),"个")

# %%
lists = []
count = 1
for j in range(12):
    count *= 10
    lists = []
    i = 0
    for i in range(1, count+1):
        if i % 7 == 0:
            lists.append(i)
    print(count, "以内，共有7的倍数", len(lists), "个")

# %%
for i in range(1,int(input())+1):print(10 ** i, "以内,共有7的倍数", len(tuple(x for x in range(7,10**i+1,7))), "个")
# Out:
# 10 以内,共有7的倍数 1 个
# 100 以内,共有7的倍数 14 个
# 1000 以内,共有7的倍数 142 个
# 10000 以内,共有7的倍数 1428 个
# 100000 以内,共有7的倍数 14285 个
# 1000000 以内,共有7的倍数 142857 个

# %%
for i in range(1,int(input())+1):
    print(10 ** i, "以内,共有7的倍数", len(tuple(x for x in range(7,10**i+1,7))), "个")

# %%
for i in range(1,int(input())+1):print(10 ** i, "以内,共有7的倍数",10**i//7, "个")
# Out:
# 10 以内,共有7的倍数 1 个
# 100 以内,共有7的倍数 14 个
# 1000 以内,共有7的倍数 142 个
# 10000 以内,共有7的倍数 1428 个
# 100000 以内,共有7的倍数 14285 个
# 1000000 以内,共有7的倍数 142857 个
# 10000000 以内,共有7的倍数 1428571 个
# 100000000 以内,共有7的倍数 14285714 个
# 1000000000 以内,共有7的倍数 142857142 个
# 10000000000 以内,共有7的倍数 1428571428 个
# 100000000000 以内,共有7的倍数 14285714285 个
# 1000000000000 以内,共有7的倍数 142857142857 个
# 10000000000000 以内,共有7的倍数 1428571428571 个
# 100000000000000 以内,共有7的倍数 14285714285714 个
# 1000000000000000 以内,共有7的倍数 142857142857142 个
# 10000000000000000 以内,共有7的倍数 1428571428571428 个
# 100000000000000000 以内,共有7的倍数 14285714285714285 个
# 1000000000000000000 以内,共有7的倍数 142857142857142857 个
# 10000000000000000000 以内,共有7的倍数 1428571428571428571 个
# 100000000000000000000 以内,共有7的倍数 14285714285714285714 个
# 1000000000000000000000 以内,共有7的倍数 142857142857142857142 个
# 10000000000000000000000 以内,共有7的倍数 1428571428571428571428 个
# 100000000000000000000000 以内,共有7的倍数 14285714285714285714285 个
# ...
