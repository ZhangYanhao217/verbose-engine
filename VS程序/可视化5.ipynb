# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
bar = Bar()
bar.add_xaxis(["规模以上工业增加值比上年同月增长（%）","规模以上工业产销率（%）","居民消费价格指数（%）",
               "限额以上消费品零售额（亿元）","比上年同月增长（%）","一般公共预算收入（亿元）",
               "一般公共预算支出（亿元）","金融机构人民币存款余额（亿元）","比上年同期增长（%）",
               "金融机构人民币贷款余额（亿元）","比上年同期增长（%）"])
bar.add_yaxis("2月",[" ","96.00" ,"105.4","4.37","-41.5","3.38","14.56","1339.20","2.6","1451.78","14.8"])
bar.add_yaxis("3月",["-5.2","97.6","104.4","10.27","4.7","7.09","22.21","1391.64","1.7","1471.22","15.5"])
bar.add_yaxis("4月",["7.9","96.8" ,"103.0","8.81","8.1","10.09","22.66","1346.53","0.7","1502.70","16.6"])
bar.set_global_opts(title_opts = opts.TitleOpts(title = "主要指标逐月完成情况",subtitle = "2月-4月"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="859008e705914c26afbb427fcd31d941" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_859008e705914c26afbb427fcd31d941 = echarts.init(
#                     document.getElementById('859008e705914c26afbb427fcd31d941'), 'white', {renderer: 'canvas'});
#                 var option_859008e705914c26afbb427fcd31d941 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
bar = Bar()
bar.add_xaxis(["规模以上工业增加值比上年同月增长（%）","规模以上工业产销率（%）","居民消费价格指数（%）",
               "限额以上消费品零售额（亿元）","比上年同月增长（%）","一般公共预算收入（亿元）",
               "一般公共预算支出（亿元）","金融机构人民币存款余额（亿元）","比上年同期增长（%）",
               "金融机构人民币贷款余额（亿元）","比上年同期增长（%）"])
bar.add_yaxis("5月",["6.9","96.4" ,"102.2","9.47","7.4","9.81","19.08","1393.73","4.4","1522.88","15.8"])
bar.add_yaxis("6月",["11.9","96.6","102.6","9.81","17.9","13.08","28.39","1432.61","6.1","1543.75","16.6"])
bar.add_yaxis("7月",["7.0","98.1","103.2","9.13","10.3","5.94","29.84","1399.20","4.9","1561.06","1561.06"])
bar.set_global_opts(title_opts = opts.TitleOpts(title = "主要指标逐月完成情况",subtitle = "5月-7月"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="af72bed59ef54deab7d78c72550b9b01" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_af72bed59ef54deab7d78c72550b9b01 = echarts.init(
#                     document.getElementById('af72bed59ef54deab7d78c72550b9b01'), 'white', {renderer: 'canvas'});
#                 var option_af72bed59ef54deab7d78c72550b9b01 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
bar = Bar()
bar.add_xaxis(["规模以上工业增加值比上年同月增长（%）","规模以上工业产销率（%）","居民消费价格指数（%）",
               "限额以上消费品零售额（亿元）","比上年同月增长（%）","一般公共预算收入（亿元）",
               "一般公共预算支出（亿元）","金融机构人民币存款余额（亿元）","比上年同期增长（%）",
               "金融机构人民币贷款余额（亿元）","比上年同期增长（%）"])
bar.add_yaxis("8月",["9.9","97.3" ,"103.7","9.54","15.1","6.26","18.91","1405.85","4.7","1569.52","15.2"])
bar.add_yaxis("9月",["11.0","97.6","102.3","11.18","18.0","6.39","40.80","1442.16","6.1","1588.29","16.6"])
bar.add_yaxis("10月",["8.2","97.2","101.2","10.99","23.0","13.11","19.14","1398.74","6.4","1622.92","17.3"])
bar.set_global_opts(title_opts = opts.TitleOpts(title = "主要指标逐月完成情况",subtitle = "5月-10月"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9cff75f6503648fd884ae349201d321b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9cff75f6503648fd884ae349201d321b = echarts.init(
#                     document.getElementById('9cff75f6503648fd884ae349201d321b'), 'white', {renderer: 'canvas'});
#                 var option_9cff75f6503648fd884ae349201d321b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
bar = Bar()
bar.add_xaxis(["规模以上工业增加值比上年同月增长（%）","规模以上工业产销率（%）","居民消费价格指数（%）",
               "限额以上消费品零售额（亿元）","比上年同月增长（%）","一般公共预算收入（亿元）",
               "一般公共预算支出（亿元）","金融机构人民币存款余额（亿元）","比上年同期增长（%）",
               "金融机构人民币贷款余额（亿元）","比上年同期增长（%）"])
bar.add_yaxis("5月",["6.9","96.4" ,"102.2","9.47","7.4","9.81","19.08","1393.73","4.4","1522.88","15.8"])
bar.add_yaxis("6月",["11.9","96.6","102.6","9.81","17.9","13.08","28.39","1432.61","6.1","1543.75","16.6"])
bar.add_yaxis("7月",["11.9","96.6","102.6","9.81","17.9","13.08","28.39","1432.61","6.1","1543.75","16.6"])
bar.set_global_opts(title_opts = opts.TitleOpts(title = "主要指标逐月完成情况",subtitle = "5月-7月"),
                                               toolbox_opts = opts.ToolboxOpts(is_show = True))
bar.reversal_axis()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f8a94ec291a642b1ad5a0d497ffca898" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f8a94ec291a642b1ad5a0d497ffca898 = echarts.init(
#                     document.getElementById('f8a94ec291a642b1ad5a0d497ffca898'), 'white', {renderer: 'canvas'});
#                 var option_f8a94ec291a642b1ad5a0d497ffca898 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
